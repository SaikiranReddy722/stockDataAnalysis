# %% [markdown]
# Analysis of stock data

# %% [markdown]
# Importing the Required Libraries

# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

import utils

# %%
#Get 5 stocks for analysis from nifty 50
stocks = utils.random_stocks(5)

# %%
data = yf.download("INFY", start="2020-01-01", end="2025-01-01")
data['Close'].plot(title="INFY Stock Price from 2020 to 2025")
# Out:
# C:\Users\mskre\AppData\Local\Temp\ipykernel_1136\3027839247.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("INFY", start="2020-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
# <Axes: title={'center': 'INFY Stock Price from 2020 to 2025'}, xlabel='Date'>

# %%
data.head()
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker          INFY      INFY      INFY      INFY      INFY
# Date
# 2020-01-02  8.967669  9.011244  8.915380  8.976385   5688000
# 2020-01-03  8.985099  9.019959  8.941524  8.967669   6992200
# 2020-01-06  8.897950  8.932810  8.863090  8.906665  10068900
# 2020-01-07  8.802086  8.863090  8.802086  8.819515  10589100
# 2020-01-08  8.793371  8.819516  8.706222  8.714937  13440400

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2020-01-02 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, INFY)   1258 non-null   float64
#  1   (High, INFY)    1258 non-null   float64
#  2   (Low, INFY)     1258 non-null   float64
#  3   (Open, INFY)    1258 non-null   float64
#  4   (Volume, INFY)  1258 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB
