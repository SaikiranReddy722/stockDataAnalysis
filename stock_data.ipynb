# %% [markdown]
# Analysis of stock data

# %% [markdown]
# Importing the Required Libraries

# %%
# %pip install -r requirements.txt

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = yf.download("INFY", start="2020-01-01", end="2025-01-01")
data['Close'].plot(title="INFY Stock Price from 2020 to 2025")
# Out:
# C:\Users\mskre\AppData\Local\Temp\ipykernel_5444\3027839247.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("INFY", start="2020-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
# <Axes: title={'center': 'INFY Stock Price from 2020 to 2025'}, xlabel='Date'>

# %%
data.head()
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker          INFY      INFY      INFY      INFY      INFY
# Date
# 2020-01-02  8.967670  9.011245  8.915380  8.976386   5688000
# 2020-01-03  8.985100  9.019960  8.941525  8.967670   6992200
# 2020-01-06  8.897950  8.932810  8.863090  8.906665  10068900
# 2020-01-07  8.802086  8.863090  8.802086  8.819515  10589100
# 2020-01-08  8.793372  8.819517  8.706222  8.714938  13440400
